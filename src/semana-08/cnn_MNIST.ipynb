# %%
import torchvision
from torchvision import transforms

# MNIST dataset
root_path = '/home/storopoli/Downloads' # mude isso no Colab se necessário

# Pequena transformação para tensores e normalizando o tamanho
trans = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])

# Train/Test Datasets
train_dataset = torchvision.datasets.MNIST(root=root_path, train=True, transform=trans, download=True)
test_dataset = torchvision.datasets.MNIST(root=root_path, train=False, transform=trans)

# %%
train_dataset
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: /home/storopoli/Downloads
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.1307,), std=(0.3081,))
#            )

# %%
from torch.utils.data import random_split

train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

# %%
test_dataset
# Out:
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: /home/storopoli/Downloads
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.1307,), std=(0.3081,))
#            )

# %%
from torch.utils.data import DataLoader

batch_size=32

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
validation_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# %%
import torch.nn as nn

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.fc1 = nn.Sequential(
            nn.Linear(7 * 7 * 64, 1000),
            nn.ReLU())
        self.fc2 = nn.Linear(1000, 10)
    
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# Instancia o Model()
model = ConvNet()

print(model)
# Out:
# ConvNet(
#   (layer1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=3136, out_features=1000, bias=True)
#     (1): ReLU()
#   )
#   (fc2): Linear(in_features=1000, out_features=10, bias=True)
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

count_parameters(model)
# Out:
# 3199106

# %%
from torch.optim import Adam, SGD 

# Hiperparâmetros
loss_fn = nn.CrossEntropyLoss()
learning_rate = 0.001
epochs = 6

# Instânciar o Otimizador Adam
optimizer = Adam(model.parameters(), lr=learning_rate)
#optimizer = SGD(model.parameters(), lr=learning_rate)

# %%
# ======== Ex 1 ========

import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# True
# NVIDIA GeForce RTX 3050 Laptop GPU
# ConvNet(
#   (layer1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=3136, out_features=1000, bias=True)
#     (1): ReLU()
#   )
#   (fc2): Linear(in_features=1000, out_features=10, bias=True)
# )

# %%
# Treinar o Modelo
total_step = len(train_loader) # quantos batches eu tenho

# Listas vazias
train_loss_epoch_list = []
train_acc_epoch_list = []

val_loss_list = []
val_acc_list = []

best_val_acc = 0

for epoch in range(epochs):
    model.train()  # Coloca o modelo em modo de treino

    train_loss = 0
    correct = 0
    total = 0

    for i, (images, labels) in enumerate(train_loader):

        images, labels = images.to(device), labels.to(device)

        # Gera a propagação (feed forward)
        outputs = model(images)

        # Calcula a função-custo
        loss = loss_fn(outputs, labels)

        # Retro-propagação (Backprop) e a otimização com Adam
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Acurácia
        train_loss += loss.item() * labels.size(0)
        _, predicted = torch.max(outputs.data, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

        if (i + 1) % 100 == 0:
            print(f"Época [{epoch+1}/{epochs}], Step [{i+1}/{total_step}], Custo: {round(loss.item(), 3)}, Acurácia: {round((correct / total) * 100, 3)}")

    # Média por época
    epoch_train_acc = correct / total
    epoch_train_loss = train_loss / len(train_loader)

    train_loss_epoch_list.append(epoch_train_loss)
    train_acc_epoch_list.append(epoch_train_acc)

   # ======= Ex 2: Loop de validação =======
    model.eval()  # Coloca o modelo em modo de avaliação

    val_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in validation_loader:
            
            images, labels = images.to(device), labels.to(device)

            # Feed-forward com as imagens de teste
            outputs = model(images)

            # Calcula a função-custo
            loss = loss_fn(outputs, labels)


            # Acurácia
            val_loss += loss.item() * images.size(0)
            total += labels.size(0)
            _, predicted = torch.max(outputs.data, 1)
            correct += (predicted == labels).sum().item()

    # Cálculos finais da época
    avg_val_loss = val_loss / len(validation_loader)
    val_accuracy = correct / total

    val_loss_list.append(avg_val_loss)
    val_acc_list.append(val_accuracy)

    print(f"[Validação] Época {epoch+1} -> Loss: {round(avg_val_loss, 3)}, Acurácia: {round(val_accuracy * 100, 3)}%")

    # ======= Ex 4: Salvar melhor modelo =======
    if val_accuracy > best_val_acc:
        best_val_acc = val_accuracy
        torch.save(model.state_dict(), 'best_val_model.pth')
        print(f"Modelo salvo com melhor acurácia de validação: {round(best_val_acc * 100, 3)}%")

# Continuação Ex 4: Carregando o melhor modelo em nova instância
best_model = ConvNet()
best_model.load_state_dict(torch.load('best_val_model.pth'))
best_model.to(device)
# Out:
# Época [1/6], Step [100/1500], Custo: 0.166, Acurácia: 84.719
# Época [1/6], Step [200/1500], Custo: 0.138, Acurácia: 89.922
# Época [1/6], Step [300/1500], Custo: 0.246, Acurácia: 91.948
# Época [1/6], Step [400/1500], Custo: 0.056, Acurácia: 93.164
# Época [1/6], Step [500/1500], Custo: 0.006, Acurácia: 93.931
# Época [1/6], Step [600/1500], Custo: 0.277, Acurácia: 94.516
# Época [1/6], Step [700/1500], Custo: 0.153, Acurácia: 94.996
# Época [1/6], Step [800/1500], Custo: 0.003, Acurácia: 95.312
# Época [1/6], Step [900/1500], Custo: 0.008, Acurácia: 95.576
# Época [1/6], Step [1000/1500], Custo: 0.003, Acurácia: 95.806
# Época [1/6], Step [1100/1500], Custo: 0.015, Acurácia: 96.017
# Época [1/6], Step [1200/1500], Custo: 0.029, Acurácia: 96.208
# Época [1/6], Step [1300/1500], Custo: 0.037, Acurácia: 96.337
# Época [1/6], Step [1400/1500], Custo: 0.012, Acurácia: 96.462
# Época [1/6], Step [1500/1500], Custo: 0.04, Acurácia: 96.583
# [Validação] Época 1 -> Loss: 1.837, Acurácia: 98.267%
# Modelo salvo com melhor acurácia de validação: 98.267%
# Época [2/6], Step [100/1500], Custo: 0.017, Acurácia: 98.781
# Época [2/6], Step [200/1500], Custo: 0.008, Acurácia: 98.844
# Época [2/6], Step [300/1500], Custo: 0.012, Acurácia: 98.729
# Época [2/6], Step [400/1500], Custo: 0.003, Acurácia: 98.648
# Época [2/6], Step [500/1500], Custo: 0.045, Acurácia: 98.631
# Época [2/6], Step [600/1500], Custo: 0.0, Acurácia: 98.677
# Época [2/6], Step [700/1500], Custo: 0.171, Acurácia: 98.728
# Época [2/6], Step [800/1500], Custo: 0.161, Acurácia: 98.676
# Época [2/6], Step [900/1500], Custo: 0.077, Acurácia: 98.684
# Época [2/6], Step [1000/1500], Custo: 0.002, Acurácia: 98.709
# Época [2/6], Step [1100/1500], Custo: 0.007, Acurácia: 98.699
# Época [2/6], Step [1200/1500], Custo: 0.0, Acurácia: 98.693
# Época [2/6], Step [1300/1500], Custo: 0.0, Acurácia: 98.716
# Época [2/6], Step [1400/1500], Custo: 0.084, Acurácia: 98.703
# Época [2/6], Step [1500/1500], Custo: 0.001, Acurácia: 98.713
# [Validação] Época 2 -> Loss: 1.616, Acurácia: 98.483%
# Modelo salvo com melhor acurácia de validação: 98.483%
# Época [3/6], Step [100/1500], Custo: 0.0, Acurácia: 99.344
# Época [3/6], Step [200/1500], Custo: 0.018, Acurácia: 99.328
# Época [3/6], Step [300/1500], Custo: 0.001, Acurácia: 99.115
# Época [3/6], Step [400/1500], Custo: 0.001, Acurácia: 99.125
# Época [3/6], Step [500/1500], Custo: 0.0, Acurácia: 99.156
# Época [3/6], Step [600/1500], Custo: 0.004, Acurácia: 99.188
# Época [3/6], Step [700/1500], Custo: 0.063, Acurácia: 99.214
# Época [3/6], Step [800/1500], Custo: 0.0, Acurácia: 99.191
# Época [3/6], Step [900/1500], Custo: 0.002, Acurácia: 99.156
# Época [3/6], Step [1000/1500], Custo: 0.001, Acurácia: 99.103
# Época [3/6], Step [1100/1500], Custo: 0.001, Acurácia: 99.082
# Época [3/6], Step [1200/1500], Custo: 0.002, Acurácia: 99.096
# Época [3/6], Step [1300/1500], Custo: 0.037, Acurácia: 99.087
# Época [3/6], Step [1400/1500], Custo: 0.013, Acurácia: 99.096
# Época [3/6], Step [1500/1500], Custo: 0.016, Acurácia: 99.09
# [Validação] Época 3 -> Loss: 1.61, Acurácia: 98.542%
# Modelo salvo com melhor acurácia de validação: 98.542%
# Época [4/6], Step [100/1500], Custo: 0.003, Acurácia: 99.438
# Época [4/6], Step [200/1500], Custo: 0.005, Acurácia: 99.359
# Época [4/6], Step [300/1500], Custo: 0.004, Acurácia: 99.469
# Época [4/6], Step [400/1500], Custo: 0.012, Acurácia: 99.414
# Época [4/6], Step [500/1500], Custo: 0.017, Acurácia: 99.45
# Época [4/6], Step [600/1500], Custo: 0.055, Acurácia: 99.422
# Época [4/6], Step [700/1500], Custo: 0.0, Acurácia: 99.429
# Época [4/6], Step [800/1500], Custo: 0.001, Acurácia: 99.426
# Época [4/6], Step [900/1500], Custo: 0.014, Acurácia: 99.413
# Época [4/6], Step [1000/1500], Custo: 0.001, Acurácia: 99.416
# Época [4/6], Step [1100/1500], Custo: 0.001, Acurácia: 99.435
# Época [4/6], Step [1200/1500], Custo: 0.058, Acurácia: 99.43
# Época [4/6], Step [1300/1500], Custo: 0.015, Acurácia: 99.421
# Época [4/6], Step [1400/1500], Custo: 0.0, Acurácia: 99.391
# Época [4/6], Step [1500/1500], Custo: 0.041, Acurácia: 99.362
# [Validação] Época 4 -> Loss: 1.549, Acurácia: 98.617%
# Modelo salvo com melhor acurácia de validação: 98.617%
# Época [5/6], Step [100/1500], Custo: 0.003, Acurácia: 99.562
# Época [5/6], Step [200/1500], Custo: 0.005, Acurácia: 99.641
# Época [5/6], Step [300/1500], Custo: 0.0, Acurácia: 99.552
# Época [5/6], Step [400/1500], Custo: 0.0, Acurácia: 99.531
# Época [5/6], Step [500/1500], Custo: 0.005, Acurácia: 99.5
# Época [5/6], Step [600/1500], Custo: 0.013, Acurácia: 99.526
# Época [5/6], Step [700/1500], Custo: 0.088, Acurácia: 99.531
# Época [5/6], Step [800/1500], Custo: 0.0, Acurácia: 99.48
# Época [5/6], Step [900/1500], Custo: 0.0, Acurácia: 99.469
# Época [5/6], Step [1000/1500], Custo: 0.002, Acurácia: 99.487
# Época [5/6], Step [1100/1500], Custo: 0.0, Acurácia: 99.486
# Época [5/6], Step [1200/1500], Custo: 0.0, Acurácia: 99.477
# Época [5/6], Step [1300/1500], Custo: 0.003, Acurácia: 99.49
# Época [5/6], Step [1400/1500], Custo: 0.003, Acurácia: 99.487
# Época [5/6], Step [1500/1500], Custo: 0.001, Acurácia: 99.477
# [Validação] Época 5 -> Loss: 1.522, Acurácia: 98.683%
# Modelo salvo com melhor acurácia de validação: 98.683%
# Época [6/6], Step [100/1500], Custo: 0.007, Acurácia: 99.594
# Época [6/6], Step [200/1500], Custo: 0.001, Acurácia: 99.656
# Época [6/6], Step [300/1500], Custo: 0.0, Acurácia: 99.625
# Época [6/6], Step [400/1500], Custo: 0.013, Acurácia: 99.625
# Época [6/6], Step [500/1500], Custo: 0.001, Acurácia: 99.606
# Época [6/6], Step [600/1500], Custo: 0.0, Acurácia: 99.594
# Época [6/6], Step [700/1500], Custo: 0.023, Acurácia: 99.594
# Época [6/6], Step [800/1500], Custo: 0.0, Acurácia: 99.602
# Época [6/6], Step [900/1500], Custo: 0.0, Acurácia: 99.59
# Época [6/6], Step [1000/1500], Custo: 0.0, Acurácia: 99.591
# Época [6/6], Step [1100/1500], Custo: 0.016, Acurácia: 99.577
# Época [6/6], Step [1200/1500], Custo: 0.002, Acurácia: 99.56
# Época [6/6], Step [1300/1500], Custo: 0.145, Acurácia: 99.56
# Época [6/6], Step [1400/1500], Custo: 0.002, Acurácia: 99.556
# Época [6/6], Step [1500/1500], Custo: 0.0, Acurácia: 99.542
# [Validação] Época 6 -> Loss: 2.062, Acurácia: 98.725%
# Modelo salvo com melhor acurácia de validação: 98.725%
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_37940\724252317.py:93: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_model.load_state_dict(torch.load('best_val_model.pth'))
# ConvNet(
#   (layer1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=3136, out_features=1000, bias=True)
#     (1): ReLU()
#   )
#   (fc2): Linear(in_features=1000, out_features=10, bias=True)
# )

# %%
import matplotlib.pyplot as plt

# ======== EX 3: Plot dos gráficos de perda e acurácia ========
epochs_range = range(1, epochs + 1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, train_loss_epoch_list, label='Training')
plt.plot(epochs_range, val_loss_list, label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, train_acc_epoch_list, label='Training')
plt.plot(epochs_range, val_acc_list, label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend()

plt.show()

# %%
model.eval() # coloca o modelo em modo de avaliação (sem calcular gradientes)

with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)
        # Feed-forward com as imagens de teste
        outputs = model(images)
        
        # gera predições usando a função max()
        _, predicted = torch.max(outputs.data, 1)
        
        # Acumula total e corretas
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
    print(f"Acurácia do Modelo em 10k imagens de teste: {round((correct / total) * 100, 3)}")
# Out:
# Acurácia do Modelo em 10k imagens de teste: 98.89
